# %%
# !python --version
# Out:
# Python 3.10.12

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.5.1+cu124
# True

# %%
from PIL import Image
import torch
import numpy as np
from transformers import AutoModelForVision2Seq, AutoTokenizer, AutoImageProcessor, StoppingCriteria, AutoProcessor, AutoModelForZeroShotObjectDetection
import argparse
import os
import json
from generated_code import code_breakfastbox, code_juicebottle, code_pushpins, code_splicingconnectors, code_screwbag
from datetime import datetime
# Out:
# in __init__.py

# %%
image = Image.open("assets/apple_strawberry.png")

from IPython.display import display
display(image.resize((300, 300)))  # Jupyter Notebookで小さいサイズで表示
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>

# %% [markdown]
# 正常条件の設定

# %%
normal_condition = """
Normal_condition1:There are two apples.
Function1:

Normal_condition2:There are six strawberries.
Function2:
"""

# %% [markdown]
# LLMs generate Anomaly Detection program.
